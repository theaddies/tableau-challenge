# %%
import pandas as pd

# %%
import numpy as np

# %%
path = "E:/tableau_data/"
bike_file = "2020-citi-data.csv"
weather_file = "NYC_weather_data_2020.csv"
weather_bike_file = '2020_citi_data_weather.csv'

# %%
bike_df = pd.read_csv(path+bike_file)

# %%
weather_df = pd.read_csv(path + weather_file)

# %%
bike_df
# Out:
#                          starttime                  stoptime  \
# 0         2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1         2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2         2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3         2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4         2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
# ...                            ...                       ...
# 11944125  2020-08-31 23:59:29.7690  2020-09-01 00:25:31.9660
# 11944126  2020-08-31 23:59:32.1320  2020-09-01 00:16:35.3710
# 11944127  2020-08-31 23:59:33.0920  2020-09-01 00:09:33.4670
# 11944128  2020-08-31 23:59:35.7900  2020-09-01 00:11:53.2310
# 11944129  2020-08-31 23:59:45.3470  2020-09-01 00:05:59.1630
#
#           start station id               start station name  \
# 0                      504                  1 Ave & E 16 St
# 1                     3423  West Drive & Prospect Park West
# ...

# %%
bike_df['starttime'] = pd.to_datetime(bike_df['starttime'])

# %%
weather_df['DATE']
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 264   2020-09-21
# 265   2020-09-22
# 266   2020-09-23
# 267   2020-09-24
# 268   2020-09-25
# Name: DATE, Length: 269, dtype: datetime64[ns]

# %%
weather_df['DATE'] = pd.to_datetime(weather_df['DATE'])

# %%
weather_df['DATE']
# Out:
# 0     2020-01-01
# 1     2020-01-02
# 2     2020-01-03
# 3     2020-01-04
# 4     2020-01-05
#          ...
# 264   2020-09-21
# 265   2020-09-22
# 266   2020-09-23
# 267   2020-09-24
# 268   2020-09-25
# Name: DATE, Length: 269, dtype: datetime64[ns]

# %%
bike_df['date'] = bike_df['starttime'].dt.date

# %%
bike_df
# Out:
#                        starttime                  stoptime  start station id  \
# 0        2020-01-01 00:00:55.390  2020-01-01 00:14:05.1470               504
# 1        2020-01-01 00:01:08.102  2020-01-01 00:26:49.1780              3423
# 2        2020-01-01 00:01:42.140  2020-01-01 00:26:07.0110              3687
# 3        2020-01-01 00:01:45.561  2020-01-01 00:11:38.1550               346
# 4        2020-01-01 00:01:45.788  2020-01-01 00:13:28.2400               372
# ...                          ...                       ...               ...
# 11944125 2020-08-31 23:59:29.769  2020-09-01 00:25:31.9660               298
# 11944126 2020-08-31 23:59:32.132  2020-09-01 00:16:35.3710              3508
# 11944127 2020-08-31 23:59:33.092  2020-09-01 00:09:33.4670               320
# 11944128 2020-08-31 23:59:35.790  2020-09-01 00:11:53.2310              3318
# 11944129 2020-08-31 23:59:45.347  2020-09-01 00:05:59.1630              3423
#
# ...

# %%
bike_df.to_csv(path+bike_file)

# %%
weather_df['DATE']
# Out:
# 0      2020-01-01
# 1      2020-01-02
# 2      2020-01-03
# 3      2020-01-04
# 4      2020-01-05
#           ...
# 264    2020-09-21
# 265    2020-09-22
# 266    2020-09-23
# 267    2020-09-24
# 268    2020-09-25
# Name: DATE, Length: 269, dtype: object

# %%
#weather_df['DATE'] = weather_df['DATE'].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-e44707070f22> in <module>
# ----> 1 weather_df['DATE'] = weather_df['DATE'].dt.date
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
# ...

# %%
weather_df.to_csv(path+weather_file)
